# %% [markdown]
# ## Goodreads
#     - Examining the representation and impact of soccer/football in contemporary literature through Goodreads and NYT Bestseller data

# %%
import pandas as pd
import altair as alt
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt

# Configure Altair settings
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
# Load datasets
goodreads_df = pd.read_csv('https://raw.githubusercontent.com/melaniewalsh/responsible-datasets-in-context/main/datasets/top-500-novels/library_top_500.csv', encoding='utf-8')
goodreads_df
# Out:
#      top_500_rank                               title                  author  \
# 0               1                         Don Quixote     Miguel de Cervantes
# 1               2    Alice's Adventures in Wonderland           Lewis Carroll
# 2               3  The Adventures of Huckleberry Finn              Mark Twain
# 3               4        The Adventures of Tom Sawyer              Mark Twain
# 4               5                     Treasure Island  Robert Louis Stevenson
# ..            ...                                 ...                     ...
# 495           496          Stranger in a Strange Land      Robert A. Heinlein
# 496           497                     Vision in White            Nora Roberts
# 497           498                    The Whipping Boy          Sid Fleischman
# 498           499                                Room           Emma Donoghue
# 499           500                     Deception Point               Dan Brown
#
#      pub_year orig_lang      genre author_birth author_death author_gender  \
# 0        1605   Spanish     action         1547         1616          male
# 1        1865   English    fantasy         1832         1898          male
# 2        1884   English     action         1835         1910          male
# 3        1876   English     action         1835         1910          male
# 4        1883   English     action         1850         1894          male
# ..        ...       ...        ...          ...          ...           ...
# 495      1961   English      scifi         1907         1988          male
# 496      2009   English    romance         1965        ALIVE        female
# 497      1986   English     action         1920         2010          male
# 498      2010   English         na         1969        ALIVE        female
# 499      2001   English  political         1964        ALIVE          male
#
#     author_primary_lang  ... gr_num_ratings gr_num_reviews gr_avg_rating_rank  \
# 0                   spa  ...        269,435         12,053                318
# 1                   eng  ...        561,016         15,380                172
# 2                   eng  ...      1,262,480         19,440                373
# 3                   eng  ...        931,898         13,603                301
# 4                   eng  ...        486,155         16,307                368
# ..                  ...  ...            ...            ...                ...
# 495                 eng  ...        311,859          9,961                310
# 496                 eng  ...        138,445          4,652                128
# 497                 eng  ...         27,444          1,623                476
# 498                 eng  ...        801,989         50,594                171
# 499                 eng  ...        658,866         10,464                420
#
#      gr_num_ratings_rank      oclc_owi  author_viaf  \
# 0                    211  1.810748e+09     17220427
# 1                    133  1.156132e+10     66462036
# 2                     68  3.373178e+09     50566653
# 3                     88  3.373178e+09     50566653
# 4                    145  3.434000e+03     95207986
# ..                   ...           ...          ...
# 495                  190  7.894120e+05     12309757
# 496                  277  1.559638e+08     66448023
# 497                  445  4.415520e+08     66438084
# 498                  101  4.859780e+08     39539889
# 499                  122  6.102510e+05    102403515
#
#                                                 gr_url  \
# 0    https://www.goodreads.com/book/show/3836.Don_Q...
# 1    https://www.goodreads.com/book/show/24213.Alic...
# 2    https://www.goodreads.com/book/show/2956.The_A...
# 3    https://www.goodreads.com/book/show/24583.The_...
# 4    https://www.goodreads.com/book/show/295.Treasu...
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
#                                               wiki_url  \
# 0            https://en.wikipedia.org/wiki/Don_Quixote
# 1    https://en.wikipedia.org/wiki/Alice%27s_Advent...
# 2    https://en.wikipedia.org/wiki/Adventures_of_Hu...
# 3    https://en.wikipedia.org/wiki/The_Adventures_o...
# 4        https://en.wikipedia.org/wiki/Treasure_Island
# ..                                                 ...
# 495  https://en.wikipedia.org/wiki/Stranger_in_a_St...
# 496      https://en.wikipedia.org/wiki/Vision_in_White
# 497     https://en.wikipedia.org/wiki/The_Whipping_Boy
# 498         https://en.wikipedia.org/wiki/Room_(novel)
# 499      https://en.wikipedia.org/wiki/Deception_Point
#
#                                             pg_eng_url  \
# 0    https://www.gutenberg.org/cache/epub/996/pg996...
# 1     https://www.gutenberg.org/cache/epub/11/pg11.txt
# 2     https://www.gutenberg.org/cache/epub/76/pg76.txt
# 3     https://www.gutenberg.org/cache/epub/74/pg74.txt
# 4    https://www.gutenberg.org/cache/epub/120/pg120...
# ..                                                 ...
# 495                                  NA_not-pub-domain
# 496                                  NA_not-pub-domain
# 497                                  NA_not-pub-domain
# 498                                  NA_not-pub-domain
# 499                                  NA_not-pub-domain
#
#                                            pg_orig_url
# 0    https://www.gutenberg.org/cache/epub/2000/pg20...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
#
# [500 rows x 29 columns]

# %% [markdown]
# Amount of Male and Female authors:

# %%
goodreads_df["author_gender"].value_counts()
# Out:
# male      354
# female    145
# Name: author_gender, dtype: int64

# %% [markdown]
# Changing `gr_num_ratings` column from string to an int

# %%
goodreads_df['gr_num_ratings'] = goodreads_df['gr_num_ratings'].str.replace(',', '').astype(int)

# %% [markdown]
# Now we are able to view the top 10 largest `gr_num_ratings`'s that corresponds to the biggest ratings in books.

# %%
top_10_rated_books = goodreads_df.nlargest(10, 'gr_num_ratings')
top_10_rated_books
# Out:
#      top_500_rank                                     title  \
# 44             45     Harry Potter and the Sorcerer's Stone
# 172           173                          The Hunger Games
# 131           132                                  Twilight
# 28             29                     To Kill a Mockingbird
# 33             34                          The Great Gatsby
# 302           303                    The Fault In Our Stars
# 85             86                      Nineteen Eighty-Four
# 5               6                       Pride and Prejudice
# 102           103  Harry Potter and the Prisoner of Azkaban
# 17             18      The Hobbit, or, There and Back Again
#
#                   author  pub_year orig_lang      genre author_birth  \
# 44          J.K. Rowling      1997   English    fantasy         1965
# 172      Suzanne Collins      2008   English      scifi         1962
# 131      Stephenie Meyer      2005   English    romance         1973
# 28            Harper Lee      1960   English         na         1926
# 33   F. Scott Fitzgerald      1925   English         na         1896
# 302           John Green      2012   English    romance         1977
# 85         George Orwell      1949   English  political         1903
# 5            Jane Austen      1813   English    romance         1775
# 102         J.K. Rowling      1999   English    fantasy         1965
# 17        J.R.R. Tolkien      1937   English    fantasy         1892
#
#     author_death author_gender author_primary_lang  ... gr_num_ratings  \
# 44         ALIVE        female                 eng  ...        9977698
# 172        ALIVE        female                 eng  ...        8603378
# 131        ALIVE        female                 eng  ...        6536249
# 28          2016        female                 eng  ...        6080747
# 33          1940          male                 eng  ...        5198202
# 302        ALIVE          male                 eng  ...        5106984
# 85          1950          male                 eng  ...        4558358
# 5           1817        female                 eng  ...        4239555
# 102        ALIVE        female                 eng  ...        4146575
# 17          1973          male                 eng  ...        3941429
#
#     gr_num_reviews gr_avg_rating_rank  gr_num_ratings_rank      oclc_owi  \
# 44         160,913                  9                    1  2.989160e+05
# 172        216,829                 22                    2  1.707209e+08
# 131        129,360                461                    3  2.875569e+09
# 28         116,479                 48                    4  1.814350e+05
# 33         103,746                298                    5  8.520100e+04
# 302        178,231                113                    6  1.035140e+09
# 85         113,880                 77                    7  1.908976e+09
# 5          113,241                 34                    8  1.881837e+09
# 102         83,149                  2                    9  3.770154e+09
# 17          70,212                 35                   10  4.061665e+09
#
#      author_viaf                                             gr_url  \
# 44     116796842  https://www.goodreads.com/book/show/42844155-h...
# 172    150638554  https://www.goodreads.com/book/show/2767052-th...
# 131    102313919  https://www.goodreads.com/book/show/41865.Twil...
# 28      12431460  https://www.goodreads.com/book/show/2657.To_Ki...
# 33     100254195  https://www.goodreads.com/book/show/4671.The_G...
# 302     41229323  https://www.goodreads.com/book/show/11870085-t...
# 85      95155403  https://www.goodreads.com/book/show/5471.Ninet...
# 5      102333412  https://www.goodreads.com/book/show/1885.Pride...
# 102    116796842  https://www.goodreads.com/book/show/5.Harry_Po...
# 17      95218067  https://www.goodreads.com/book/show/437049.The...
#
#                                               wiki_url  \
# 44   https://en.wikipedia.org/wiki/Harry_Potter_and...
# 172  https://en.wikipedia.org/wiki/The_Hunger_Games...
# 131  https://en.wikipedia.org/wiki/Twilight_(Meyer_...
# 28   https://en.wikipedia.org/wiki/To_Kill_a_Mockin...
# 33      https://en.wikipedia.org/wiki/The_Great_Gatsby
# 302  https://en.wikipedia.org/wiki/The_Fault_in_Our...
# 85   https://en.wikipedia.org/wiki/Nineteen_Eighty-...
# 5    https://en.wikipedia.org/wiki/Pride_and_Prejudice
# 102  https://en.wikipedia.org/wiki/Harry_Potter_and...
# 17            https://en.wikipedia.org/wiki/The_Hobbit
#
#                                             pg_eng_url  pg_orig_url
# 44                                   NA_not-pub-domain          NaN
# 172                                  NA_not-pub-domain          NaN
# 131                                  NA_not-pub-domain          NaN
# 28                                   NA_not-pub-domain          NaN
# 33   https://www.gutenberg.org/cache/epub/64317/pg6...          NaN
# 302                                  NA_not-pub-domain          NaN
# 85                                   NA_not-pub-domain          NaN
# 5    https://www.gutenberg.org/cache/epub/1342/pg13...          NaN
# 102                                  NA_not-pub-domain          NaN
# 17                                   NA_not-pub-domain          NaN
#
# [10 rows x 29 columns]

# %%
genre_count = goodreads_df['genre'].value_counts().reset_index()
genre_count.columns = ['genre', 'count']

bar_chart = alt.Chart(genre_count).mark_bar().encode(
    x='genre',
    y='count'
).properties(
    title='Number of Books by Genre'
)
bar_chart
# Out:
# alt.Chart(...)

# %%
# Initial Data Exploration

# Check for missing values in the Goodreads dataset
goodreads_missing_values = goodreads_df.isnull().sum().sum()
print("Missing values in Goodreads dataset:", goodreads_missing_values)
# Out:
# Missing values in Goodreads dataset: 707

# %%
# Display the structure of the Goodreads dataset
print("Structure of Goodreads dataset:\n", goodreads_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   top_500_rank              500 non-null    int64
#  1   title                     500 non-null    object
#  2   author                    500 non-null    object
#  3   pub_year                  500 non-null    int64
#  4   orig_lang                 500 non-null    object
#  5   genre                     500 non-null    object
#  6   author_birth              499 non-null    object
#  7   author_death              496 non-null    object
#  8   author_gender             499 non-null    object
#  9   author_primary_lang       499 non-null    object
#  10  author_nationality        499 non-null    object
#  11  author_field_of_activity  329 non-null    object
#  12  author_occupation         458 non-null    object
#  13  oclc_holdings             495 non-null    float64
#  14  oclc_eholdings            495 non-null    float64
#  15  oclc_total_editions       495 non-null    float64
#  16  oclc_holdings_rank        495 non-null    float64
#  17  oclc_editions_rank        495 non-null    float64
#  18  gr_avg_rating             500 non-null    float64
#  19  gr_num_ratings            500 non-null    int64
#  20  gr_num_reviews            500 non-null    object
#  21  gr_avg_rating_rank        500 non-null    int64
#  22  gr_num_ratings_rank       500 non-null    int64
#  23  oclc_owi                  495 non-null    float64
#  24  author_viaf               500 non-null    object
#  25  gr_url                    480 non-null    object
#  26  wiki_url                  500 non-null    object
#  27  pg_eng_url                500 non-null    object
#  28  pg_orig_url               64 non-null     object
# dtypes: float64(7), int64(5), object(17)
# memory usage: 113.4+ KB
# Structure of Goodreads dataset:
#  None

# %%
# Display summary statistics for the Goodreads dataset
goodreads_summary = goodreads_df.describe()
print("Summary statistics for Goodreads dataset:\n", goodreads_summary)
# Out:
# Summary statistics for Goodreads dataset:
#         top_500_rank     pub_year  oclc_holdings  oclc_eholdings  \
# count    500.000000   500.000000     495.000000      495.000000
# mean     250.500000  1932.132000   10401.438384     2218.593939
# std      144.481833    84.306546    5694.509003     3084.595715
# min        1.000000  1021.000000     996.000000       25.000000
# 25%      125.750000  1900.000000    6800.000000      352.000000
# 50%      250.500000  1948.000000    8318.000000      558.000000
# 75%      375.250000  1989.000000   12184.000000     3223.000000
# max      500.000000  2015.000000   37702.000000    15545.000000
#
#        oclc_total_editions  oclc_holdings_rank  oclc_editions_rank  \
# count           495.000000          495.000000          495.000000
# mean            896.642424          248.000000          248.000000
# std            1019.015572          143.038456          143.038456
# min              21.000000            1.000000            1.000000
# 25%             241.000000          124.500000          124.500000
# 50%             485.000000          248.000000          248.000000
# 75%            1207.500000          371.500000          371.500000
# max            9017.000000          495.000000          495.000000
#
#        gr_avg_rating  gr_num_ratings  gr_avg_rating_rank  gr_num_ratings_rank  \
# count     500.000000    5.000000e+02          500.000000           500.000000
# mean        3.971440    6.035750e+05          250.500000           250.500000
# std         0.227688    1.094771e+06          144.481833           144.481833
# min         3.290000    2.200000e+01            1.000000             1.000000
# 25%         3.830000    6.122675e+04          125.750000           125.750000
# 50%         3.980000    1.843000e+05          250.500000           250.500000
# 75%         4.120000    6.232955e+05          375.250000           375.250000
# max         4.620000    9.977698e+06          500.000000           500.000000
#
#            oclc_owi
# count  4.950000e+02
# mean   1.602208e+09
# std    2.675299e+09
# min    1.040000e+03
# 25%    3.972875e+05
# 50%    1.675603e+07
# 75%    2.830459e+09
# max    1.239276e+10

# %% [markdown]
# ## New York Times BestSellers
#     - tabular data of fiction bestseller list of The NYT between 1931-2020

# %%
nyt_bestseller_df = pd.read_csv('nyt_bestseller.csv')

# %%
# Check for missing values in the New York Times Bestseller dataset
nyt_missing_values = nyt_bestseller_df.isnull().sum().sum()
print("Missing values in New York Times Bestseller dataset:", nyt_missing_values)
# Out:
# Missing values in New York Times Bestseller dataset: 10

# %%
# Display the structure of the New York Times Bestseller dataset
print("Structure of New York Times Bestseller dataset:\n", nyt_bestseller_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60386 entries, 0 to 60385
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0    year     60386 non-null  int64
#  1   week      60386 non-null  object
#  2   rank      60386 non-null  int64
#  3   title_id  60386 non-null  int64
#  4   title     60386 non-null  object
#  5   author    60376 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 2.8+ MB
# Structure of New York Times Bestseller dataset:
#  None

# %%
# Display summary statistics for the New York Times Bestseller dataset
nyt_summary = nyt_bestseller_df.describe()
print("Summary statistics for New York Times Bestseller dataset:\n", nyt_summary)
# Out:
# Summary statistics for New York Times Bestseller dataset:
#                 year          rank      title_id
# count  60386.000000  60386.000000  60386.000000
# mean    1980.291375      7.578329   3810.020154
# std       24.440366      4.401472   2118.650219
# min     1931.000000      1.000000      0.000000
# 25%     1958.000000      4.000000   2012.000000
# 50%     1982.000000      7.000000   3931.500000
# 75%     2001.000000     11.000000   5599.000000
# max     2020.000000     18.000000   7430.000000

# %%
# chart = alt.Chart(nyt_bestseller_df).mark_bar().encode(
#     x='author',
#     y='count()'
# ).properties(
#     title='Number of Bestsellers by Author'
# )
# chart
